# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("D:\workspace\dataset\covid19\covid.csv")

# %%
df
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 1                             Andhra Pradesh    2339067       3  2324331
# 2                          Arunachal Pradesh      66890       0    66594
# 3                                      Assam     746100       0   738065
# 4                                      Bihar     851379      15   839062
# 5                                 Chandigarh      99348       6    98161
# 6                               Chhattisgarh    1177749       6  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 8                                      Delhi    2007188      35  1980632
# 9                                        Goa     259079      26   255040
# 10                                   Gujarat    1277557      41  1266473
# 11                                   Haryana    1056602      43  1045845
# ...

# %%
place= array[17:21,:]
print(place)
# Out:
# [['Ladakh' 29412 3 29178 231 219564 186942 68766 53990 564943 307204]
#  ['Lakshadweep' 11415 0 11363 52 56908 55992 15757 6949 145008 72210]
#  ['Madhya Pradesh' 1054918 4 1044138 10776 54140166 54035268 9854998
#   3787239 133590886 82342793]
#  ['Maharashtra' 8136588 164 7988008 148416 84644083 71593498 5022623
#   4450343 177678317 120837347]]

# %%
i1 = np.max(df)
i2 = np.argmax(df)

print("i1:", i1)
print("i2:", i2)
# Out:
# c:\Users\psingh\miniconda3\envs\course\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 i1 = np.max(df)
# ----> 2 i2 = np.argmax(df)
#       4 print("i1:", i1)
#       5 print("i2:", i2)
#
# File <__array_function__ internals>:180, in argmax(*args, **kwargs)
#
# File c:\Users\psingh\miniconda3\envs\course\lib\site-packages\numpy\core\fromnumeric.py:1216, in argmax(a, axis, out, keepdims)
#    1129 """
#    1130 Returns the indices of the maximum values along an axis.
#    1131
#    (...)
#    1213 (2, 1, 4)
#    1214 """
# ...

# %%
## converting data_frame_values into numpy_array
array = df.values

# print(array)
total_doses =array[:,9]       ## select all rows of column 3 ie. Covid deaths 
deaths = array[:,4]      ## select all rows of column 2 ie. Covid passive cases

# print("X:", x_deaths, "Y:", y_passive)


## Reshape array into 1-dim Tensor
y = deaths.reshape(-1,1)
x = total_doses.reshape(-1,1)

# %%
rho1=df['total_doses'].corr(df['deaths'])
print(rho1)
# Out:
# 0.43967544731829616

# %%
# Compute correlation coefficient
corr_1 = np.corrcoef(total_doses, deaths)[0, 1]

print("Correlation coefficient:", corr_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Compute correlation coefficient
# ----> 2 corr_1 = np.corrcoef(total_doses, deaths)[0, 1]
#       4 print("Correlation coefficient:", corr_1)
#
# File <__array_function__ internals>:180, in corrcoef(*args, **kwargs)
#
# File c:\Users\psingh\miniconda3\envs\course\lib\site-packages\numpy\lib\function_base.py:2845, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2841 if bias is not np._NoValue or ddof is not np._NoValue:
#    2842     # 2015-03-15, 1.10
#    2843     warnings.warn('bias and ddof have no effect and are deprecated',
#    2844                   DeprecationWarning, stacklevel=3)
# -> 2845 c = cov(x, y, rowvar, dtype=dtype)
#    2846 try:
#    2847     d = diag(c)
#
# File <__array_function__ internals>:180, in cov(*args, **kwargs)
#
# ...

# %%
# Compute correlation coefficient
corr_matrix = np.corrcoef(total_doses.flatten(), deaths.flatten())
corr_1 = corr_matrix[0, 1]  # Extract the correlation coefficient from the matrix

print("Correlation coefficient:", corr_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Compute correlation coefficient
# ----> 2 corr_matrix = np.corrcoef(total_doses.flatten(), deaths.flatten())
#       3 corr_1 = corr_matrix[0, 1]  # Extract the correlation coefficient from the matrix
#       5 print("Correlation coefficient:", corr_1)
#
# File <__array_function__ internals>:180, in corrcoef(*args, **kwargs)
#
# File c:\Users\psingh\miniconda3\envs\course\lib\site-packages\numpy\lib\function_base.py:2845, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2841 if bias is not np._NoValue or ddof is not np._NoValue:
#    2842     # 2015-03-15, 1.10
#    2843     warnings.warn('bias and ddof have no effect and are deprecated',
#    2844                   DeprecationWarning, stacklevel=3)
# -> 2845 c = cov(x, y, rowvar, dtype=dtype)
#    2846 try:
#    2847     d = diag(c)
#
# ...

# %%
corr_1 =np.corr(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 corr_1 =np.corr(x,y)
#
# File c:\Users\psingh\miniconda3\envs\course\lib\site-packages\numpy\__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'corr'

# %%
 = prn[iii, :]
x = prn[8, :]
y = prn[3, :]

corr_matrix = np.corrcoef(prn.T)

plt.plot(y, x, 'ko')
plt.show()

prn_size = prn.shape

x = prn[:, 8]
y = prn[:, 3]

a = np.corrcoef(x, y)[0, 1] * np.std(y) / np.std(x)

prn = prn * 1000

a = np.corrcoef(x, y)[0, 1] * np.std(y) / np.std(x)

x = prn[:, 8]
y = prn[:, 3]

a = np.corrcoef(x, y)[0, 1] * np.std(y) / np.std(x)

x = prn[:, 8]
y = prn[:, 3]

a = np.corrcoef(x, y)[0, 1] * np.std(y) / np.std(x)

b = np.mean(y) - a * np.mean(x)

yc = a * x + b

error1 = 100 * (y - yc) / yc

error2 = 100 * (y - yc) / y

deter = np.corrcoef(x, y)[0, 1] ** 2

X = prn[:, [4, 5, 6, 7]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 prn = prn[iii, :]
#       5 x = prn[8, :]
#       6 y = prn[3, :]
#
# NameError: name 'prn' is not defined

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x)
y_predict
# Out:
# array([[ -2484.57788996],
#        [ 30302.95973272],
#        [ -1691.2611859 ],
#        [  7824.10376336],
#        [  9255.32464077],
#        [ -1243.92760731],
#        [ 13854.2856738 ],
#        [ -2470.76123842],
#        [ 25432.42709959],
#        [   979.1928817 ],
#        [ 15312.13371865],
#        [ 12185.63095378],
#        [  1735.46678871],
#        [  4090.67446643],
#        [  3561.07867021],
#        [ 54478.27377627],
#        [ 93093.94426565],
#        [ -2221.48050281],
#        [ -2473.93552554],
#        [ 12161.4411854 ],
#        [110562.49977202],
#        [  -682.58893986],
#        [ -1286.48289405],
#        [   741.09300564],
#        [ -2136.08651083],
#        [ 16173.48503197],
#        [  -175.90752881],
#        [  8203.91288597],
#        [ 15868.21497305],
#        [ -2014.00399493],
#        [ 47760.80202004],
#        [  9228.11646544],
#        [ -1117.33873736],
#        [ 27186.67420453],
#        [  3622.92058541],
# ...

# %%
plt.figure(figsize=(12,6))
plt.scatter(x,y)
plt.plot(x, y_predict, color="red")
plt.xlabel("Number of Passive Covid Cases")
plt.ylabel("Covid Deaths")
plt.show()

# %%
# print(array)
deaths = array[:,4]       ## select all rows of column 3 ie. Covid deaths 
total_doses = array[:,9]      ## select all rows of column 2 ie. Covid passive cases

# print("X:", x_deaths, "Y:", y_passive)


## Reshape array into 1-dim Tensor
y = deaths.reshape(-1,1)
x = total_doses.reshape(-1,1)

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x)
y_predict
# Out:
# array([[ 5694.39209131],
#        [22216.5723197 ],
#        [ 5833.20055114],
#        [13127.7111289 ],
#        [29249.80124583],
#        [ 5889.07411656],
#        [12956.44732074],
#        [ 5782.94463745],
#        [11179.68555366],
#        [ 5978.08991199],
#        [24815.90137486],
#        [12399.75919229],
#        [ 7848.89596118],
#        [ 9275.34263793],
#        [12133.21878652],
#        [23780.57282277],
#        [14212.43816126],
#        [ 5630.1041875 ],
#        [ 5566.77912444],
#        [25690.05687076],
#        [32338.32231313],
#        [ 6037.4061797 ],
#        [ 5940.16077257],
#        [ 5814.9628244 ],
#        [ 5806.93075716],
#        [17826.6696714 ],
#        [ 5887.61681148],
#        [12627.90660616],
#        [22935.6195251 ],
#        [ 5750.06358835],
#        [24762.91904603],
#        [17186.72137876],
#        [ 6437.07616988],
#        [64452.29269987],
#        [ 8568.65658859],
#        [29063.68707063]])

# %%
print(df_copy['deaths'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(df_copy['deaths'])
#
# NameError: name 'df_copy' is not defined

# %%
df_copy.shape
# Out:
# (36, 11)

# %%
df_copy.describe()
# Out:
#           confirmed       active       passive         deaths         dose1  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000  3.600000e+01
# mean   1.241053e+06    98.666667  1.226213e+06   14741.611111  2.555372e+07
# std    1.833873e+06   305.722844  1.808032e+06   27168.565338  3.234424e+07
# min    1.074200e+04     0.000000  1.061200e+04       4.000000  5.690800e+04
# 25%    1.058625e+05     1.000000  1.048608e+05    1120.750000  1.045166e+06
# 50%    6.127550e+05    10.500000  6.063365e+05    6541.000000  1.777784e+07
# 75%    1.320729e+06    46.750000  1.311100e+06   14292.750000  4.281102e+07
# max    8.136588e+06  1389.000000  7.988008e+06  148416.000000  1.540583e+08
#
#               dose2         dose3  precaution_dose   total_doses    population
# count  3.600000e+01  3.600000e+01     3.600000e+01  3.600000e+01  3.600000e+01
# mean   2.398740e+07  4.286358e+06     1.892749e+06  6.098716e+07  3.712387e+07
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            36 non-null     object
#  1   confirmed        36 non-null     int64
#  2   active           36 non-null     int64
#  3   passive          36 non-null     int64
#  4   deaths           36 non-null     int64
#  5   dose1            36 non-null     int64
#  6   dose2            36 non-null     int64
#  7   dose3            36 non-null     int64
#  8   precaution_dose  36 non-null     int64
#  9   total_doses      36 non-null     int64
#  10  population       36 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.2+ KB

# %%
print(df_copy.columns)
# Out:
# Index(['state', 'confirmed', 'active', 'passive', 'deaths', 'dose1', 'dose2',
#        'dose3', 'precaution_dose', 'total_doses', 'population'],
#       dtype='object')

# %%
print(df_copy.isna().sum())
# Out:
# state              0
# confirmed          0
# active             0
# passive            0
# deaths             0
# dose1              0
# dose2              0
# dose3              0
# precaution_dose    0
# total_doses        0
# population         0
# dtype: int64

# %%
print(df_copy.memory_usage())
# Out:
# Index              128
# state              288
# confirmed          288
# active             288
# passive            288
# deaths             288
# dose1              288
# dose2              288
# dose3              288
# precaution_dose    288
# total_doses        288
# population         288
# dtype: int64

# %%
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            36 non-null     object
#  1   confirmed        36 non-null     int64
#  2   active           36 non-null     int64
#  3   passive          36 non-null     int64
#  4   deaths           36 non-null     int64
#  5   dose1            36 non-null     int64
#  6   dose2            36 non-null     int64
#  7   dose3            36 non-null     int64
#  8   precaution_dose  36 non-null     int64
#  9   total_doses      36 non-null     int64
#  10  population       36 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.2+ KB
# None
# state              object
# confirmed           int64
# active              int64
# passive             int64
# deaths              int64
# dose1               int64
# dose2               int64
# dose3               int64
# ...

# %%
col=df.columns.values
for i in col[1:]:
    print(df[i].describe())
    print(df[i].shape)
    print(df[i].isna())
    print(df[i].value_counts())
# Out:
# count    3.600000e+01
# mean     1.241053e+06
# std      1.833873e+06
# min      1.074200e+04
# 25%      1.058625e+05
# 50%      6.127550e+05
# 75%      1.320729e+06
# max      8.136588e+06
# Name: confirmed, dtype: float64
# (36,)
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# Name: confirmed, dtype: bool
# 10742      1
# 2339067    1
# 8136588    1
# 139922     1
# 96783      1
# 238964     1
# 35986      1
# 1336552    1
# 175508     1
# 784205     1
# 1315455    1
# 44319      1
# 3594388    1
# 841324     1
# 108034     1
# ...

# %%
disease_feature= ['confirmed','active','passive','deaths']
treatment_feature=['dose1','dose2','dose3','precaution_dose',]

# %%
list(enumerate(disease_feature))
# Out:
# [(0, 'confirmed'), (1, 'active'), (2, 'passive'), (3, 'deaths')]

# %%
list(enumerate(treatment_feature))
# Out:
# [(0, 'dose1'), (1, 'dose2'), (2, 'dose3'), (3, 'precaution_dose')]

# %%
#rho1=df['dose3'].corr(df['deaths'])
#print(rho1)

rho2=df['total_doses'].corr(df['deaths'])
print(rho2)
# Out:
# 0.43967544731829616

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df_copy.corr(),cmap='RdBu', annot=True)
# Out:
# C:\Users\psingh\AppData\Local\Temp\ipykernel_6428\52907921.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_copy.corr(),cmap='RdBu', annot=True)
# <Axes: >

# %%
y = df_copy['deaths'] # dependent variable
x = df_copy['total_doses'] # independent variable
#z= df['deaths']
plt.figure(figsize=(12,8))
plt.scatter(x=x, y=y, color='blue')
plt.xlim([50000,450000000])
plt.ylim([0,200000])
num_points = len(x)
print(num_points)
plt.show()
# Out:
# 36

# %%
print(max(df_copy['passive']))
print(max(df_copy['dose1']))
print(min(df_copy['dose1']))
print(min(df_copy['passive']))
# Out:
# 7988008
# 154058287
# 56908
# 10612

# %%
y = df_copy['passive'] # dependent variable
x = df_copy['dose1'] # independent variable
#z= df['deaths']
plt.figure(figsize=(12,8))
plt.scatter(x=x, y=y, color='blue')
plt.xlim([40000,10000000])
plt.ylim([0,1000000])
num_points = len(x)
print(num_points)
plt.show()
# Out:
# 36

# %%
print(df_copy['dose1'])
# Out:
# 0        313284
# 1      40643161
# 2        860442
# 3      22549957
# 4      62944633
# 5       1089254
# 6      18955635
# 7        730746
# 8      16600054
# 9       1354828
# 10     49314588
# 11     21955717
# 12      6041658
# 13      9941757
# 14     21300448
# 15     50016690
# 16     27013745
# 17       219564
# 18        56908
# 19     54140166
# 20     84644083
# 21      1463998
# 22      1332102
# 23       785749
# 24       837775
# 25     31453659
# 26       912901
# 27     22352681
# 28     51103054
# 29       539927
# 30     56659544
# 31     29607672
# 32      2658852
# 33    154058287
# 34      8180312
# 35     67300236
# Name: dose1, dtype: int64

# %%
print(df_copy['total_doses'])
# Out:
# 0        991263
# 1     110556756
# 2       1911760
# 3      50284713
# 4     157197041
# 5       2282281
# 6      49148991
# 7       1578492
# 8      37366540
# 9       2872582
# 10    127793995
# 11     45457359
# 12     15278680
# 13     24738045
# 14     43689818
# 15    120928298
# 16     57477992
# 17       564943
# 18       145008
# 19    133590886
# 20    177678317
# 21      3265933
# 22      2621058
# 23      1790818
# 24      1737554
# 25     81445474
# 26      2272617
# 27     46970300
# 28    115325059
# 29      1360444
# 30    127442647
# 31     77201709
# 32      5916312
# 33    390639497
# 34     20051714
# 35    155962840
# Name: total_doses, dtype: int64

# %%
#import scipy.stats
#x= df_copy['total_doses']
#y= df_copy['deaths']
#scipy.stats.pearsonr(x, y)[0]

# %%
#z=df_copy['dose1']
#a=df_copy['dose3']
#b=df_copy['active']
#np.corrcoef(z,y)
#np.corrcoef(a,y)
#np.corrcoef(b,a)

# %%
#np.corrcoef(x,y)

# %%
dup=df_copy.duplicated()
print(dup.sum())
# Out:
# 0

# %%
rho2=df_copy['total_doses'].corr(df_copy['deaths'])
print(rho2)
# Out:
# 0.43967544731829616

# %%
std_y=df_copy['deaths'].std()
std_z=df_copy['total_doses'].std()

a2= rho2* std_y/std_z
print(a2)
# Out:
# 0.0001507972973606723

# %%
mean_y= df_copy['deaths'].mean()
mean_z= df_copy['total_doses'].mean()

b2=mean_y-a2*mean_z

print(b2)
# Out:
# 5544.912309939742

# %%
det2=rho2*rho2
print(det2)
# Out:
# 0.19331449897454384

# %%
y_pred2 = a2*(df_copy['total_doses']) +b2
print(y_pred2)
# Out:
# 0      5694.392091
# 1     22216.572320
# 2      5833.200551
# 3     13127.711129
# 4     29249.801246
# 5      5889.074117
# 6     12956.447321
# 7      5782.944637
# 8     11179.685554
# 9      5978.089912
# 10    24815.901375
# 11    12399.759192
# 12     7848.895961
# 13     9275.342638
# 14    12133.218787
# 15    23780.572823
# 16    14212.438161
# 17     5630.104188
# 18     5566.779124
# 19    25690.056871
# 20    32338.322313
# 21     6037.406180
# 22     5940.160773
# 23     5814.962824
# 24     5806.930757
# 25    17826.669671
# 26     5887.616811
# 27    12627.906606
# 28    22935.619525
# 29     5750.063588
# 30    24762.919046
# 31    17186.721379
# 32     6437.076170
# 33    64452.292700
# 34     8568.656589
# 35    29063.687071
# Name: total_doses, dtype: float64

# %%
print(df_copy['deaths'])
# Out:
# 0        129
# 1      14733
# 2        296
# 3       8035
# 4      12302
# 5       1181
# 6      14146
# 7          4
# 8      26521
# 9       4013
# 10     11043
# 11     10714
# 12      4213
# 13      4785
# 14      5331
# 15     40307
# 16     71552
# 17       231
# 18        52
# 19     10776
# 20    148416
# 21      2149
# 22      1624
# 23       726
# 24       782
# 25      9205
# 26      1975
# 27     19289
# 28      9653
# 29       499
# 30     38049
# 31      4111
# 32       940
# 33     23633
# 34      7751
# 35     21532
# Name: deaths, dtype: int64

# %%
y_abs2= (df_copy['deaths']-y_pred2).abs()
print(y_abs2)
# Out:
# 0       5565.392091
# 1       7483.572320
# 2       5537.200551
# 3       5092.711129
# 4      16947.801246
# 5       4708.074117
# 6       1189.552679
# 7       5778.944637
# 8      15341.314446
# 9       1965.089912
# 10     13772.901375
# 11      1685.759192
# 12      3635.895961
# 13      4490.342638
# 14      6802.218787
# 15     16526.427177
# 16     57339.561839
# 17      5399.104188
# 18      5514.779124
# 19     14914.056871
# 20    116077.677687
# 21      3888.406180
# 22      4316.160773
# 23      5088.962824
# 24      5024.930757
# 25      8621.669671
# 26      3912.616811
# 27      6661.093394
# 28     13282.619525
# 29      5251.063588
# 30     13286.080954
# 31     13075.721379
# 32      5497.076170
# 33     40819.292700
# 34       817.656589
# 35      7531.687071
# dtype: float64

# %%
y_abst2= (100*y_abs2)/y_pred2
print(y_abst2)
# Out:
# 0      97.734613
# 1      33.684640
# 2      94.925599
# 3      38.793595
# 4      57.941595
# 5      79.945914
# 6       9.181164
# 7      99.930831
# 8     137.224919
# 9      32.871535
# 10     55.500307
# 11     13.595096
# 12     46.323661
# 13     48.411609
# 14     56.062772
# 15     69.495497
# 16    403.446342
# 17     95.897056
# 18     99.065887
# 19     58.053810
# 20    358.947742
# 21     64.405244
# 22     72.660673
# 23     87.514967
# 24     86.533333
# 25     48.363883
# 26     66.455018
# 27     52.748992
# 28     57.912626
# 29     91.321835
# 30     53.653129
# 31     76.080371
# 32     85.397097
# 33     63.332569
# 34      9.542413
# 35     25.914424
# dtype: float64

# %%
#y_abs2= (y-y_pred2).abs()
#print(y_abs2)

# %%
#y_abst2= 100*y_abs2/y_pred2
#print(y_abst2)

# %%
#me1 = y_abst1.mean()
#print(me1)

me2 = y_abst2.mean()
print(me2)
# Out:
# 81.35752104134191

# %%
##y = df_copy['passive'] # dependent variable
#x = df_copy['dose1'] # independent variable
#z= df['deaths']
#plt.figure(figsize=(10,6))
#plt.scatter(x=x, y=y, s=30,color='blue')
#plt.xlim([40000,10000000])
#plt.ylim([0,1000000])
#num_points = len(x)
#print(num_points)
#plt.plot(x, y_pred1, color='red')
#plt.show()

# %%
y = df_copy['deaths'] # dependent variable
x = df_copy['total_doses'] # independent variable
#z= df['deaths']
plt.figure(figsize=(10,6))
plt.scatter(x=x, y=y, color='blue')
plt.xlim([50000,400000000])
plt.ylim([0,150000])
num_points = len(x)
print(num_points)
plt.plot(x, y_pred2, color='red')
plt.show()
# Out:
# 36

# %%
print(max(df_copy['passive']))
print(min(df_copy['passive']))
print(max(df_copy['dose3']))
print(min(df_copy['dose3']))
# Out:
# 7988008
# 10612
# 35623544
# 15757

# %%
y = df_copy['active'] # dependent variable
x = df_copy['dose3'] # independent variable
#z= df['deaths']
plt.figure(figsize=(10,6))
plt.scatter(x=x, y=y, color='blue')
plt.xlim([10000,50000000])
plt.ylim([0,1500])
num_points = len(x)
print(num_points)
plt.show()
# Out:
# 36

# %%
rho1=df_copy['passive'].corr(df_copy['dose3'])
print(rho1)
# Out:
# 0.24645978702991153

# %%
std_a=df_copy['passive'].std()
#std_x=df_copy['dose1'].std()
std_x=df_copy['dose3'].std()

#a1= rho1* std_a/std_x
a1= rho1* std_a/std_x
#print(a1)
print(a1)
# Out:
# 0.0649293453065262

# %%
mean_a= df_copy['passive'].mean()
#mean_x= df_copy['dose1'].mean()
mean_x= df_copy['dose3'].mean()

#b1=mean_a-a1*mean_x
b1=mean_a-a2*mean_x

#print(b1)
print(b1)
# Out:
# 1225566.5453893477

# %%
y_pred1 = a1*df_copy['dose3'] +b1
print(y_pred1)
# Out:
# 0     1.240951e+06
# 1     1.985452e+06
# 2     1.230268e+06
# 3     1.360793e+06
# 4     2.003648e+06
# 5     1.228714e+06
# 6     1.598110e+06
# 7     1.234460e+06
# 8     1.375735e+06
# 9     1.229517e+06
# 10    2.099491e+06
# 11    1.307073e+06
# 12    1.322008e+06
# 13    1.285957e+06
# 14    1.310409e+06
# 15    1.597419e+06
# 16    1.281055e+06
# 17    1.230031e+06
# 18    1.226590e+06
# 19    1.865445e+06
# 20    1.551682e+06
# 21    1.232969e+06
# 22    1.227560e+06
# 23    1.230733e+06
# 24    1.227259e+06
# 25    1.874557e+06
# 26    1.245271e+06
# 27    1.277509e+06
# 28    1.510425e+06
# 29    1.235843e+06
# 30    1.617318e+06
# 31    1.909011e+06
# 32    1.243191e+06
# 33    3.538580e+06
# 34    1.312971e+06
# 35    1.891568e+06
# Name: dose3, dtype: float64

# %%
y_abs1= (df_copy['passive']-y_pred1).abs()
print(y_abs1)
# Out:
# 0     1.230339e+06
# 1     3.388786e+05
# 2     1.163674e+06
# 3     6.227279e+05
# 4     1.164586e+06
# 5     1.130553e+06
# 6     4.345133e+05
# 7     1.222873e+06
# 8     6.048967e+05
# 9     9.744767e+05
# 10    8.330177e+05
# 11    2.612279e+05
# 12    1.013600e+06
# 13    8.113491e+05
# 14    8.731729e+05
# 15    2.432892e+06
# 16    5.474249e+06
# 17    1.200853e+06
# 18    1.215227e+06
# 19    8.213071e+05
# 20    6.436326e+06
# 21    1.095196e+06
# 22    1.132402e+06
# 23    9.924952e+05
# 24    1.192055e+06
# 25    5.473008e+05
# 26    1.071743e+06
# 27    5.126421e+05
# 28    2.047109e+05
# 29    1.192024e+06
# 30    1.938961e+06
# 31    1.071869e+06
# 32    1.136097e+06
# 33    1.434156e+06
# 34    8.713712e+05
# 35    2.054481e+05
# dtype: float64

# %%
y_abst1= (100*y_abs1)/y_pred1
print(y_abst1)
# Out:
# 0      99.144849
# 1      17.068080
# 2      94.587031
# 3      45.762138
# 4      58.123275
# 5      92.011080
# 6      27.189193
# 7      99.061371
# 8      43.968971
# 9      79.256890
# 10     39.677133
# 11     19.985716
# 12     76.671244
# 13     63.093014
# 14     66.633620
# 15    152.301444
# 16    427.323561
# 17     97.627866
# 18     99.073610
# 19     44.027407
# 20    414.796661
# 21     88.825913
# 22     92.248201
# 23     80.642595
# 24     97.131493
# 25     29.196276
# 26     86.065041
# 27     40.128255
# 28     13.553199
# 29     96.454324
# 30    119.887430
# 31     56.147874
# 32     91.385552
# 33     40.529138
# 34     66.366360
# 35     10.861261
# dtype: float64

# %%
me1 = y_abst1.mean()
print(me1)
# Out:
# 87.96686302011757

# %%
y = df_copy['passive'] # dependent variable
x = df_copy['dose3'] # independent variable
#z= df['deaths']
plt.figure(figsize=(12,8))
plt.scatter(x=x, y=y, color='blue')
plt.xlim([0,40000000])
plt.ylim([0,1000000])
num_points = len(x)
print(num_points)

plt.plot(x, y_pred1, color='red')
plt.show()
# Out:
# 36

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
y = df_copy['deaths'] # dependent variable
X = df_copy[['dose1','dose2','dose3']] # independent variable

X = sm.add_constant(X) # adding a constant
lm = sm.OLS(y, X).fit() # fitting the model
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 deaths   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     20.30
# Date:                Fri, 14 Apr 2023   Prob (F-statistic):           1.49e-07
# Time:                        08:15:03   Log-Likelihood:                -398.95
# No. Observations:                  36   AIC:                             805.9
# Df Residuals:                      32   BIC:                             812.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1464.3248   3597.057      0.407      0.687   -5862.640    8791.289
# ...

# %%
# Linear equation: 𝑦 = 𝑎𝑥 + 𝑏
y_pred = -0.0024*df_copy['dose2'] + 1464.3248
print(y_pred)

# plotting the data points
plt.figure(figsize=(6, 4), tight_layout=True)
plt.scatter(x=df_copy['dose2'], y=y)

#plotting the line
plt.plot(df_copy['dose2'],y_pred, color='red')

#axes
#plt.xlim(0)
#plt.ylim(0)
#plt.savefig('linear_regression')
plt.show()
# Out:
# 0        695.4056
# 1    -103053.4072
# 2       -328.9000
# 3     -47883.9712
# 4    -140482.2040
# 5       -738.1576
# 6     -43019.6488
# 7         36.4952
# 8     -32972.8792
# 9      -1473.6904
# 10   -117163.5544
# 11    -43493.3056
# 12    -12408.2848
# 13    -23464.3960
# 14    -37046.2432
# 15   -119629.5160
# 16    -55636.1848
# 17      1015.6640
# 18      1329.9440
# 19   -128220.3184
# 20   -170360.0704
# 21     -1477.1128
# 22      -995.4400
# 23      -140.8288
# 24      -178.0096
# 25    -70415.0896
# 26      -460.1224
# 27    -45582.6520
# 28   -110160.3352
# 29       242.4032
# 30   -126935.4904
# 31    -68264.5744
# 32     -4124.3464
# 33   -353054.0992
# 34    -17593.0960
# 35   -146359.9600
# Name: dose2, dtype: float64
